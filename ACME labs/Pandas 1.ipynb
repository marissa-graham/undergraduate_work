# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

def prob1():
    val = -3
    a = pd.Series(val, index=range(2,12,2))
    print a, '\n'
    d = {'Bill': 31, 'Sarah': 28, 'Jane': 34, 'Joe': 26}
    b = pd.Series(d)
    print b
    
def prob2():
    N = 100
    s = np.zeros(N)
    for i in xrange(5):
        s[1:] = np.random.binomial(1, .5, size=(N-1,))*2-1
        s = pd.Series(s)
        s = s.cumsum()
        s.plot()
    s.plot()
    plt.ylim([-50,50])
    plt.show()
    plt.close()
    
    s1 = np.zeros(100)
    s2 = np.zeros(10000)
    s3 = np.zeros(100000)
    
    s1[1:] = np.random.binomial(1,.51, size=(99,))*2-1
    s2[1:] = np.random.binomial(1,.51, size=(9999,))*2-1
    s3[1:] = np.random.binomial(1,.51, size=(99999,))*2-1
    
    s1 = pd.Series(s1)
    s2 = pd.Series(s2)
    s3 = pd.Series(s3)
    
    s1 = s1.cumsum()
    s2 = s2.cumsum()
    s3 = s3.cumsum()
    
    s1.plot()
    #plt.ylim([-50,50])
    plt.show()
    plt.close()
    
    s2.plot()
    #plt.ylim([-50,50])
    plt.show()
    plt.close()
    
    s3.plot()
    #plt.ylim([-50,50])
    plt.show()
    plt.close()


name = ['Bill', 'Alice', 'Joe', 'Jenny', 'Ted', 'Taylor', 'Tracy', 'Morgan', 'Liz']
sex = ['M', 'F', 'M', 'F', 'M', 'F', 'M', 'M', 'F']
age = [20, 21, 18, 22, 19, 20, 20, 19, 20]
rank = ['Sp', 'Se', 'Fr', 'Se', 'Sp', 'J', 'J', 'J', 'Se']
ID = range(9)
aid = ['y', 'n', 'n', 'y', 'n', 'n', 'n', 'y', 'n']
GPA = [3.8, 3.5, 3.0, 3.9, 2.8, 2.9, 3.8, 3.4, 3.7]
mathID = [0, 1, 5, 6, 3]
mathGd = [4.0, 3.0, 3.5, 3.0, 4.0]
major = ['y', 'n', 'y', 'n', 'n']
studentInfo = pd.DataFrame({'ID': ID, 'Name': name, 'Sex': sex, 'Age': age, 'Class': rank})
otherInfo = pd.DataFrame({'ID': ID, 'GPA': GPA, 'Financial_Aid': aid})
mathInfo = pd.DataFrame({'ID': mathID, 'Grade': mathGd, 'Math_Major': major})    

def prob3():
    # SELECT ID, Name from studentInfo WHERE Age > 19 AND Sex='M'
    print studentInfo[(studentInfo['Age']>19)&(studentInfo['Sex']=='M')][['ID','Name']]
    
def prob4():
    # Use a join operation to create a DataFram containing the ID, age,
    # and GPA of all male individuals
    
    # Need to join studentInfo and otherInfo
    
    joined = pd.merge(studentInfo, otherInfo, on='ID', how='outer')
    print joined[joined['Sex']=='M'][['ID','Age','GPA']]

def prob5():
    data = pd.read_csv('crime_data.txt',skiprows=1,index_col=0)
    # Insert a new column containing the crime rate by year
        # (ratio of Total to Population columns)
    data['Crime-Rate'] = data['Total']/data['Population']
    
    # Plot the crime rate as a function of the year
    data['Crime-Rate'].plot()
    plt.show()
    plt.close()
    
    # List the 5 years with the highest crime rate in descending order
    print 'Years with highest crime rate: '
    print data['Crime-Rate'].nlargest(5)
    
    # Calculate the average number of total crimes as well as burglary
        # crimes between 1960 and 2012
    avgcrimes = data['Total'].sum()/53.
    print 'Average number of total crimes: ', avgcrimes
    avgburglaries = data['Burglary'].sum()/53.
    print 'Average number of burglary crimes: ', avgburglaries
        
    # Find the years for which the total number of crimes was below average,
        # but the number of burglaries was above average.
    print data[(data['Total']<avgcrimes)&(data['Burglary']>avgburglaries)].index
        
    # Plot the number of murders as a function of the population.
    data.plot(x='Population',y='Murder')
    plt.show()
    
    # Selected the Population, Violent, and Robbery Columns for all years
        # in the 1980s, and save this smaller data frame to a csv file
        # crime_subset.txt
    subset = pd.DataFrame({'Population':data['Population'].loc[1980:1989],'Violent':data['Violent'].loc[1980:1989],'Robbery':data['Robbery'].loc[1980:1989]})
    print subset
    subset.to_csv('crime_subset.txt')

# %%
prob4()
# Out:
#    ID  Age  GPA
# 0   0   20  3.8
# 2   2   18  3.0
# 4   4   19  2.8
# 6   6   20  3.8
# 7   7   19  3.4

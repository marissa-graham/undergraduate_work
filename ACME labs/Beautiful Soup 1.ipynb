# %%
from bs4 import BeautifulSoup
import re

#Problem 1
# Part 1 (Tags used)
print "Problem 1, part 1:"
print "html, head, title, style, body, div, h1, p, and meta\n"

# Part 2 (Value of the type attribute associated with the style tag)
print "Problem 1, part 2:"
print "text/css\n"

#Problem 2
print "Problem 2:"
html_doc = """
<html><head><title>The Three Stooges</title></head>
<body>
<p class="title"><b>The Three Stooges</b></p>
<p class="story">Have you ever met the three stooges? Their names are
<a href="http://example.com/larry" class="stooge" id="link1">Larry</a>,
<a href="http://example.com/mo" class="stooge" id="link2">Mo</a> and
<a href="http://example.com/curly" class="stooge" id="link3">Curly</a>;
and they are really hilarious.</p>
<p class="story">...</p>
"""

soup = BeautifulSoup(html_doc, 'html.parser')
print(soup.prettify())
print "\n"

#Problem 3
print "Problem 3:"
print 'soup.p returns <p class="title"><b>The Three Stooges</b></p>\n'

# Problem 4
# Part 1
print "Problem 4, part 1:"
print 'soup.a.next_sibling.next_sibling.string\n'

# Part 2
print "Problem 4, part 2:"
print 'soup.p.next_sibling.next_sibling\n'


# Part 3
print "Problem 4, part 3:"
ex_soup = BeautifulSoup(open('example.htm'),'html.parser')
print 'ex_soup.p.next_sibling.next_sibling.string'
print 'ex_soup.a.string\n'

# Problem 5
print "Problem 5:"
print ex_soup.a
print ex_soup.find(href=True)
print 'using the commands ex_soup.a and ex_soup.find(href=True)\n'

#Problem 6
SOUP = BeautifulSoup(open('SanDiegoWeather.htm'),'html.parser')

# Part 1
print "Problem 6:, part 1:"
print "h2 with the attribute class='history-date'\n"

# Part 2
print "Problem 6, part 2:"
print "tag is a, with class='previous-date' and 'next-date', respectively\n"

# Part 3
print "Problem 6, part 3:\ntd\n"

#Problem 7
print "Problem 7:"
dates_soup = BeautifulSoup(open('Big-Data-dates1.htm'))

matchy = '20(03[01][29]|0[4-9]|1.*)'
x = dates_soup.find_all('a',href=re.compile(matchy))
for i in xrange(len(x)):
    print x[i]
# Out:
# Problem 1, part 1:
# html, head, title, style, body, div, h1, p, and meta
#
# Problem 1, part 2:
# text/css
#
# Problem 2:
# <html>
#  <head>
#   <title>
#    The Three Stooges
#   </title>
#  </head>
#  <body>
#   <p class="title">
#    <b>
#     The Three Stooges
#    </b>
#   </p>
#   <p class="story">
#    Have you ever met the three stooges? Their names are
#    <a class="stooge" href="http://example.com/larry" id="link1">
#     Larry
#    </a>
#    ,
#    <a class="stooge" href="http://example.com/mo" id="link2">
#     Mo
#    </a>
#    and
#    <a class="stooge" href="http://example.com/curly" id="link3">
#     Curly
#    </a>
#    ;
# and they are really hilarious.
#   </p>
#   <p class="story">
#    ...
#   </p>
#  </body>
# </html>
#
#
# Problem 3:
# soup.p returns <p class="title"><b>The Three Stooges</b></p>
#
# Problem 4, part 1:
# soup.a.next_sibling.next_sibling.string
#
# Problem 4, part 2:
# soup.p.next_sibling.next_sibling
#
# Problem 4, part 3:
# ...

# %%
f = dict()
f['color_blind_list'] = ['cpt_plot']
f['ratio_markers'] = ['cpt_global_plot_ratio']
f['local_knots_to_segment_rows'] = ['Bfunc','spline_basis','extract_cell']
f['dup'] = ['local_knots_to_segment_rows','l2_project','approx_l2_project']
f['equal'] = ['ExtractCache','computeExtractionOperator','SegElem'\
             'get_isecting_elems','new_get_isecting_elems']
f['bernstein_basis'] = ['Bfunc','bernstein_basis_sympy','bernstein_basis_vector',\
                       'interval_bernstein_vector','fine_coarse_projection_op',\
                       'coarse_projection_op','sympy_gramian','gramian']
f['ExtractCache'] = []
f['Bfunc'] = []
f['bernstein_basis_sympy'] = []
f['degree_projection_op'] = ['project_pts','new_project_pts','multid_project_pts']
f['computeExtractionOperator'] = ['spline_dual_ext_ops','spline_dual_funcs',\
                                 'l2_project','get_elems','approx_l2_project']
f['bernstein_basis_poly'] = ['bernstein_basis_vector','coarse_projection_op',\
                            'fine_coarse_projection_op']
f['bernstein_basis_vector'] = []
f['spline_basis'] = ['spline_basis_funcs','SplineFunc','get_elem_func_weights']
f['window'] = ['spline_basis_funcs','plot_basis']
f['spline_basis_funcs'] = ['SplineFunc','get_elem_func_weights','eval_curve',\
                          'spline_func','tangent_func','eval_curve_2d',\
                          'plot_curve2']
f['build_1d_connects'] = ['spline_dual_funcs','spline_dual_ext_ops',\
                         'sympy_spline_dual_ext_ops']
f['build_1d_rev_connects'] = ['spline_dual_funcs','spline_dual_ext_ops',\
                             'sympy_spline_dual_ext_ops']
f['bernstein_horner'] = ['ExtractionFunc']
f['spline_dual_ext_ops'] = []
f['sympy_spline_dual_ext_ops'] = []
f['spline_dual_funcs'] = []
f['BernsteinBasis'] = ['bern_eval','eval_bernstein_pts','Elem','subinterval_op',\
                      'get_coeff_weights']
f['bern_eval'] = []
f['eval_bernstein_pts'] = []
f['Elem'] = ['l2_project','approx_l2_project','multid_local_l2_project']
f['ten_prod'] = ['LocalAssemblyL2New','BElem']
f['SplineFunc'] = []
f['BElem'] = ['SparseAssembleL2','func_from_ext','func_from_sol',\
             'plot_func_from_ext','compute_func_weights','update_elem_bounds',\
             'multid_project_pts','multid_smooth_pts','multid_local_l2_project']
f['LocalAssemblyL2New'] = ['multid_local_l2_project']
f['SparseAssembleL2'] = []
f['func_from_ext'] = ['plot_func_from_ext']
f['func_from_sol'] = []
f['plot_func_from_ext'] = []
f['LocalAssemblyL2'] = ['AssembleL2','approx_l2_project','multid_local_l2_project']
f['LocalSqDiffL2'] = ['L2Error']
f['AssembleL2'] = ['l2_project']
f['L2Error'] = ['convergence_compare']
f['l2_project'] = ['convergence_compare','cpt_plot']
f['get_coeff_weights'] = []
f['get_unique_knots'] = ['get_knot_multiplicities','get_elems','get_elem_bounds',\
                        'get_elem_func_weights','calc_elem_elem_maps','extract_cell',\
                        'approx_l2_project','extend_knot_vector','refine_knot_vector',\
                        'coarsen_knot_vector','reduce_knot_vector',\
                        'smooth_knot_vector','elevate_knot_vector',\
                        'roughen_knot_vector','shift_interior_knots',\
                        'get_knot_vector_labels','l2_project','spline_dual_funcs',\
                        'sympy_spline_dual_ext_ops','spline_dual_ext_ops',\
                        'build_1d_connects','Bfunc']
f['get_knot_multiplicities'] = ['get_elems','extract_cell','extend_knot_vector',\
                                'refine_knot_vector','coarsen_knot_vector',\
                                'elevate_knot_vector','reduce_knot_vector',\
                                'roughen_knot_vector','smooth_knot_vector',\
                                'shift_interior_knots','get_knot_vector_labels']
f['get_elems'] = ['get_elem_func_weights','project_pts','new_project_pts',\
                  'smooth_pts','select_pts','approx_l2_project']
f['get_elem_func_weights'] = []
f['integrate_funcs'] = ['smooth_pts','select_pts','approx_l2_project',\
                       'cpt_global_plot_ratio']
f['integrate_funcs_sq'] = ['smooth_pts','select_pts','approx_l2_project',\
                          'cpt_global_plot_ratio']
f['subinterval_op'] = ['project_pts','new_project_pts','multid_project_pts']
f['fine_coarse_projection_op'] = []
f['coarse_projection_op'] = []
f['get_elem_bounds'] = ['calc_elem_elem_maps']
f['get_isecting_elems'] = ['calc_elem_elem_maps']
f['calc_elem_elem_maps'] = ['new_project_pts']
f['project_pts'] = []
f['overlap_frac'] = ['new_project_pts']
f['sympy_gramian'] = ['spline_dual_ext_ops','sympy_spline_dual_ext_ops']
f['gramian'] = ['spline_dual_funcs','new_project_pts','multid_project_pts']
f['inv_gramian'] = ['multid_project_pts']
f['new_project_pts'] = []
f['compute_func_weights'] = ['multid_smooth_pts']
f['new_overlap_frac'] = ['multid_project_pts']
f['update_elem_bounds'] = ['new_calc_elem_elem_maps']
f['new_get_isecting_elems'] = ['new_calc_elem_elem_maps']
f['new_calc_elem_elem_maps'] = ['multid_project_pts']
f['kron_all'] = ['multid_project_pts']
f['multid_project_pts'] = []
f['smooth_pts'] = ['approx_l2_project','multid_local_l2_project']
f['select_pts'] = ['approx_l2_project']
f['multid_smooth_pts'] = ['multid_local_l2_project']
f['legendre_project'] = ['approx_l2_project']
f['legendre_bernstein_mat'] = ['legendre_bernstein','approx_l2_project']
f['bernstein_legendre_mat'] = ['approx_l2_project']
f['legendre_bernstein'] = ['approx_l2_project']
f['approx_l2_project'] = ['convergence_compare', 'cpt_example', 'cpt_plot']
f['multid_local_l2_project'] = []
f['new_color_cycle'] = ['cpt_bezier_plot', 'bezier_seg_plot','cpt_global_plot_ratio',\
                       'global_seg_plot']
f['convergence_compare'] = []
f['extract_cell'] = []
f['cpt_bezier_plot'] = ['cpt_plot']
f['extend_knot_vector'] = []
f['bezier_seg_plot'] = ['cpt_example','cpt_plot']
f['cpt_local_plot'] = ['cpt_example','cpt_plot']
f['cpt_global_plot_ratio'] = ['cpt_example','cpt_plot']
f['cpt_global_plot'] = ['cpt_plot']
f['global_seg_plot'] = ['cpt_example','cpt_plot']
f['cpt_example'] = []
f['cpt_plot'] = []
f['eval_curve'] = ['plot_curve']
f['deriv_pts'] = ['tangent_func']
f['spline_func'] = ['eval_tangent','eval_unit_tangent','eval_unit_normal']
f['tangent_func'] = ['unit_tangent_func','eval_tangent']
f['unit_tangent_func'] = ['unit_normal_func','eval_unit_tangent']
f['unit_normal_func'] = ['eval_unit_normal']
f['eval_tangent'] = []
f['eval_unit_tangent'] = []
f['eval_unit_normal'] = []
f['plot_curve'] = []
f['plot_curve_2d'] = []
f['eval_curve_2d'] = ['plot_curve_2d']
f['refine_knot_vector'] = []
f['coarsen_knot_vector'] = []
f['elevate_knot_vector'] = []
f['reduce_knot_vector'] = []
f['roughen_knot_vector'] = []
f['smooth_knot_vector'] = []
f['shift_interior_knots'] = []
f['format_knot_label'] = ['get_knot_vector_labels']
f['get_knot_vector_labels'] = []
f['SegElem'] = []
f['plot_basis'] = []
f['plot_curve2'] = []

# %%
print f['integrate_funcs']
print len(f)
# Out:
# ['smooth_pts', 'select_pts', 'approx_l2_project', 'cpt_global_plot_ratio']
# 110

# %%
import networkx as nx
from matplotlib import pyplot as plt

G = nx.DiGraph()
G.add_nodes_from(f.keys()) 

for key, value in f.iteritems():
    for i in xrange(len(value)):
        G.add_edge(key,value[i])
        
#subgraphs = nx.connected_components(G)

nx.draw_networkx(G,arrows=True)
plt.show()

# %%
import itertools
def equal( a, b, tol = 1e-12 ):
    try:
        return all(abs(a-b) < tol)
    except TypeError:
        return abs(a-b) < tol


class ExtractCache():
    
    def __init__(self, init_extract_rows = [], tol = 1e-12):
        self.extract_rows = init_extract_rows
        self.tol = tol
    def row_index( self, input_row ):
        
        for row, irow in zip(self.extract_rows, itertools.count()):
            # If all the elements in input_row and row are equal, return 
            if all(map(lambda x, y : equal(x,y,tol=self.tol), input_row, row)):
                return irow
        self.extract_rows.append(input_row)
        return len(self.extract_rows)-1
    
thing = ExtractCache([[1,2],[3,4],[5,6]])
print thing.row_index([3,6])
# Out:
# 3
